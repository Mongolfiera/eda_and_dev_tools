# %% [markdown]
# # Проект
#
# ## [(dataset Shoppers)](https://github.com/aiedu-courses/eda_and_dev_tools/blob/main/datasets/online_shoppers_intention.csv)
#
# ## [Online Shoppers Purchasing Intention Dataset](https://github.com/aiedu-courses/eda_and_dev_tools/tree/main/datasets#readme)
#
# The **Revenue** attribute can be used as the class label.
#
# **Administrative, Administrative Duration, Informational, Informational Duration, Product Related and Product Related Duration** represent the number of different types of pages visited by the visitor in that session and total time spent in each of these page categories. The values of these features are derived from the URL information of the pages visited by the user and updated in real time when a user takes an action, e.g. moving from one page to another.
#
# The **Bounce Rate, Exit Rate and Page Value** features represent the metrics measured by "Google Analytics" for each page in the e-commerce site. The value of Bounce Rate feature for a web page refers to the percentage of visitors who enter the site from that page and then leave ("bounce") without triggering any other requests to the analytics server during that session. The value of "Exit Rate" feature for a specific web page is calculated as for all pageviews to the page, the percentage that were the last in the session. The Page Value feature represents the average value for a web page that a user visited before completing an e-commerce transaction.
#
# The **Special Day** feature indicates the closeness of the site visiting time to a specific special day (e.g. Mother’s Day, Valentine's Day) in which the sessions are more likely to be finalized with transaction. The value of this attribute is determined by considering the dynamics of e-commerce such as the duration between the order date and delivery date. For example, for Valentina’s day, this value takes a nonzero value between February 2 and February 12, zero before and after this date unless it is close to another special day, and its maximum value of 1 on February 8.
#
# The dataset also includes **operating system, browser, region, traffic type, visitor type** as returning or new visitor, a Boolean value indicating whether the date of the visit is **weekend**, and **month of the year**.
#
# --------------
# **Bounce Rate** — это метрика, которая измеряет процент посетителей, покинувших сайт после просмотра только одной страницы, не совершая никаких действий (например, перехода на другую страницу или заполнения формы) 23. Высокий показатель отказов может указывать на то, что пользователи не находят нужную информацию или не заинтересованы в контенте сайта.
#
# Для разных типов сайтов существуют свои нормы показателя отказов. Например, для интернет-магазинов нормальным считается уровень от 10% до 40%, в то время как для новостных сайтов — до 60% 12. Показатели выше 70% могут указывать на необходимость серьезного анализа и оптимизации сайта.
#
# Причины высокого Bounce Rate:
# - Нерелевантный контент или плохое качество информации.
# - Долгая загрузка страниц или технические неполадки.
# - Неудобный интерфейс или сложная навигация.
# - Неправильные настройки рекламы, приводящие на сайт нецелевых пользователей
#
# **Exit Rate** — это метрика, которая измеряет процент пользователей, покинувших сайт с определенной страницы, по отношению к общему количеству просмотров этой страницы. Это отличается от показателя отказов (Bounce Rate), который фиксирует процент пользователей, покинувших сайт после просмотра только одной страницы.
#
# Как и в случае с Bounce Rate, для разных типов сайтов существуют свои нормы Exit Rate. Например, для интернет-магазинов нормальным считается уровень от 20% до 40%, в то время как для информационных сайтов этот показатель может быть выше.
#
# Причины высокого Exit Rate:
# - Нерелевантный или некачественный контент на странице.
# - Технические проблемы или медленная загрузка страницы.
# - Плохая навигация или отсутствие ясных призывов к действию.
# - Успешное завершение задачи (например, завершение покупки).
#
# **Page Value** — это метрика, которая измеряет среднюю ценность страницы для завершения транзакции на сайте. Она рассчитывается на основе дохода, полученного от пользователей, которые посетили эту страницу перед завершением покупки. Page Value помогает понять, какие страницы наиболее эффективны в привлечении дохода.
#
# Page Value может варьироваться в зависимости от типа контента и его роли в процессе покупки. Например, страницы с продуктами обычно имеют более высокий Page Value, чем информационные страницы.
#
# Причины высокого Page Value:
# - Страницы с высококачественным контентом, который привлекает пользователей и побуждает их к покупке.
# - Эффективные призывы к действию и навигация, которые направляют пользователей к завершению транзакции.
# - Страницы, которые обеспечивают пользователям необходимую информацию о продукте или услуге.
#
# ### Additional Information
#
# The dataset consists of feature vectors belonging to 12,330 sessions.
# The dataset was formed so that each session would belong to a different user in a 1-year period to avoid any tendency to a specific campaign, special day, user profile, or period.
#
# *[original dataset](https://archive.ics.uci.edu/dataset/468/online+shoppers+purchasing+intention+dataset)*
#
# ## I. Разведочный анализ данных
#
# - общее исследование датасета
# - однофакторный анализ
# - влияние пар факторов на целевую переменную
# - комментарии текстом (markdown) ко всем исследованиям

# %% [markdown]
# ### В рамках этой части задания ответьте в ноутбуке на следующие вопросы:
#
# - Общее исследование данных: проверить размеры таблицы, число столбцов, количество пропусков в столбцах (1 балл).
# - Однофакторный анализ: по каждому столбцу посмотреть его распределение. Если есть пропуски и ошибочные значения - обработать их. Посмотреть связь с целевой переменной (3 балла).
# - Построить матрицу корреляций (или ее аналог для категориальных признаков): использовать корреляции, тест χ2, ANOVA (2 балла).
# - Провести анализ целевой переменной - на какое распределение больше всего похожа ее гистограмма? Какие проблемы в связи с этим могут возникнуть при обучении моделей? (1 балл)
# - Увеличить размер данных простым дублированием до 1_000_000 строк в датасете. Провести сравнение скорости работы Pandas и Polars на увеличенном датасете по параметрам:
#     - загрузка данных (1 балл)
#     - фильтрация данных (1 балл)
#     - агрегация данных (1 балл)
#
# **ВАЖНО**
#
# Кроме непосредственно кода в ноутбуке не забывайте делать выводы текстом!
#
# Выводы - самая важная часть исследования

# %%
# !pip install association-metrics -q

# %%
# !pip install polars

# %%
import numpy as np

import pandas as pd
import polars as pl

import matplotlib.pyplot as plt
import seaborn as sns

import association_metrics as am
from scipy.stats import f_oneway

# %% [markdown]
# # 1. Общее исследование данных

# %%
url = "https://raw.githubusercontent.com/aiedu-courses/eda_and_dev_tools/refs/heads/main/datasets/online_shoppers_intention.csv"
df = pd.read_csv(url)

# %%
df.sample(5)
# Out:
#       Administrative  Administrative_Duration  Informational  \
# 1562               0                      0.0              0
# 9706               0                      0.0              0
# 8714               4                    170.5              0
# 5859               0                      0.0              0
# 1772               0                      0.0              0
#
#       Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 1562                     0.0               2                73.000000
# 9706                     0.0              38              1244.350000
# 8714                     0.0              20              1052.833333
# 5859                     0.0               1                 0.000000
# 1772                     0.0              14               494.000000
#
#       BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 1562     0.050000   0.150000         0.0         0.0   Mar                 2
# ...

# %%
df.shape
# Out:
# (12330, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12131 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  11839 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12231 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
# ...

# %%
df.describe(include='all').T
# Out:
#                            count unique                top   freq  \
# Administrative           12330.0    NaN                NaN    NaN
# Administrative_Duration  12330.0    NaN                NaN    NaN
# Informational            12330.0    NaN                NaN    NaN
# Informational_Duration   12131.0    NaN                NaN    NaN
# ProductRelated           12330.0    NaN                NaN    NaN
# ProductRelated_Duration  11839.0    NaN                NaN    NaN
# BounceRates              12330.0    NaN                NaN    NaN
# ExitRates                12231.0    NaN                NaN    NaN
# PageValues               12330.0    NaN                NaN    NaN
# SpecialDay               12330.0    NaN                NaN    NaN
# Month                      12330     11                May   3348
# OperatingSystems         12330.0    NaN                NaN    NaN
# Browser                  12330.0    NaN                NaN    NaN
# ...

# %%
observations = df.shape[0]

describe = df.describe(include='all').T
describe[describe["count"]<observations]["count"]/observations
# Out:
# Informational_Duration     0.983861
# ProductRelated_Duration    0.960178
# ExitRates                  0.991971
# Name: count, dtype: object

# %%
df.duplicated().sum()
# Out:
# 109

# %%
for col in ['SpecialDay', 'Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType']:
    print(f"{col} - {df[col].nunique()}")
# Out:
# SpecialDay - 6
# Month - 11
# OperatingSystems - 8
# Browser - 13
# Region - 9
# TrafficType - 20
# VisitorType - 3

# %%
df["VisitorType"].value_counts()
# Out:
# VisitorType
# Returning_Visitor    10551
# New_Visitor           1694
# Other                   85
# Name: count, dtype: int64

# %% [markdown]
# # Общее исследование данных - выводы
#
# ## Размер данных, пропуски и дубликаты
# - В датасете 12330 строк, 18 колонок.
# - В датасете есть пропуски в колонках "Informational_Duration" (~ 2%), "ProductRelated_Duration" (~ 4%), "ExitRates" (в пределах 1 % от числа записей в колонке).
# - Большая часть пропусков в колонке "Informational_Duration" соответствует 0 посещенных "Informational" страниц, в этом случае можно пропуски заполнить нулями. В остальных случаях можно взять среднее, медиану или рассчитать сренее время на 1 страницу и умножить на число страниц.
# - В датасете есть дубликаты (109 записей), но так как в датасете нет уникального id пользователя, согласно описанию, это могут быть данные разных пользователей с идентичным поведением.
#
# ## Типы переменных
# Датасет состоит из 10 числовых и 8 категориальных признаков (часть из которых закодирована цифровыми значениями).
#
# 1. Числовые переменные
# - Administrative: Количество страниц, относящихся к административной категории.
# - Administrative Duration: Общее время, проведенное на страницах административной категории.
# - Informational: Количество информационных страниц.
# - Informational Duration: Время, проведенное на информационных страницах.
# - Product Related: Количество страниц, связанных с продуктами.
# - Product Related Duration: Время, проведенное на страницах с продуктами.
# - Bounce Rate: Процент посетителей, покинувших сайт без взаимодействия.
# - Exit Rate: Процент выходов со страницы.
# - Page Value: Средняя ценность страницы перед завершением транзакции.
# - Special Day: Значение, указывающее на близость к специальному дню (числовое значение).
#
# 2. Категориальные переменные
# - Operating System: Операционная система пользователя (категория) - 8 типов.
# - Browser: Браузер, используемый для доступа к сайту (категория) - 13 типов.
# - Region: Регион, откуда пришел пользователь (категория) - 9 типов.
# - Traffic Type: Тип трафика (например, органический, реферальный и т.д.) (категория) - 20 типов.
# - Visitor Type: Тип посетителя (новый или возвращающийся) (категория) - 3 типа, есть 85 строк с типом "Other".
# - Month of the Year: Месяц посещения (категория).
# - Weekend: Указывает, является ли день выходным.
# - Revenue: Целевая переменная, указывающая была ли выручка.

# %% [markdown]
# # 2. Однофакторный анализ:
# ### по каждому столбцу посмотреть его распределение. Если есть пропуски и ошибочные значения - обработать их. Посмотреть связь с целевой переменной

# %% [markdown]
# ## Распределение числовых переменых

# %%
import warnings
warnings.filterwarnings(action="ignore")

numerical_cols = ['Administrative', 'Administrative_Duration', 'Informational', 
                  'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
                  'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay']

plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_cols):
    
    plt.subplot(10, 2, i*2 + 1)
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Distribution of {col}')
    
    plt.subplot(10, 2, i*2 + 2)
    sns.histplot(np.log(df[col]), bins=30, kde=True)
    plt.title(f'Distribution of log of {col}')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Распределение категориальных переменных

# %%
categorical_cols = ['OperatingSystems', 'Browser', 'Region', 'TrafficType', 
                    'VisitorType', 'Weekend', 'Month', 'Revenue']

plt.figure(figsize=(15, 10))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 3, i + 1)
    sns.countplot(y=df[col])
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Выводы о распределении переменных
#
# Почти все числовые переменные имеют скошенное вправо распределение - большинство пользователей посещают небольшое число страниц и проводят на них не очень много времени.
# Время, проведенное на страницах после логарифмического преобразования становится похоже на нормальное.
#
# Отношения (rates) имеют и низкие и высокие значения (картинки похожи на бета-распределение)
#
# В категориальных переменных есть значения, которые встречаются значительно чаще других, нопример, регион "1", браузер "2", операционная система "2".

# %% [markdown]
# ## Заполним пропуски и удалим дубликаты

# %%
# удалим дубликаты

df.drop_duplicates(inplace=True)

df.shape
# Out:
# (12221, 18)

# %%
# Заполним пропуски во времени посещения страниц - разобьем по количеству просмотренных страниц и возьмем медиану для каждой такой группы, 
# оставшиеся заполним медианой по всем данным

def fill_missing_with_median(df, group_col, target_col):
    # Группируем по количеству просмотренных страниц и вычисляем медиану
    median_values = df[(df[group_col]>0)&(df[target_col].notnull())].groupby(group_col)[target_col].median()
    
    # Заполняем пропуски в целевом столбце медианными значениями по группам
    for group_value in median_values.index:
        df.loc[(df[group_col] == group_value) & (df[target_col].isna()), target_col] = median_values[group_value]
        
    # Для нулевых значений посещения страниц время на страницах заполним нулями
    df.loc[(df[group_col] == 0) & (df[target_col].isna()), target_col] = 0
    
    # Оставшиеся пропуски заполним медианными значениями по всем данным
    df.loc[df[target_col].isna(), target_col] = df[target_col].median()

# Заполнение пропусков для Informational_Duration
fill_missing_with_median(df, 'Informational', 'Informational_Duration')

# Заполнение пропусков для ProductRelated_Duration
fill_missing_with_median(df, 'ProductRelated', 'ProductRelated_Duration')

# %%
# пропуски в ExitRates заполним медианой

ExitRates_median = df[df["ExitRates"].notnull()]["ExitRates"].median()

df.loc[(df["ExitRates"].isna()), "ExitRates"] = ExitRates_median

df[df["ExitRates"].notnull()]["ExitRates"].median()
# Out:
# 0.025

# %%
# Согласно описанию, "VisitorType" может принимать только 2 занчения. Заменим "Other" на "Returning_Visitor"

df.loc[df["VisitorType"]=="Other", "VisitorType"] = "Returning_Visitor"

# %%
# В месяцах есть "aug" и 'Aug' - поправим

df.loc[df["Month"]=="aug", "Month"] = "Aug"

# %%
# Заменим типы у булевых переменных

df['Revenue'] = df['Revenue'].astype(int)
df['Weekend'] = df['Weekend'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12221 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12221 non-null  int64
#  1   Administrative_Duration  12221 non-null  float64
#  2   Informational            12221 non-null  int64
#  3   Informational_Duration   12221 non-null  float64
#  4   ProductRelated           12221 non-null  int64
#  5   ProductRelated_Duration  12221 non-null  float64
#  6   BounceRates              12221 non-null  float64
#  7   ExitRates                12221 non-null  float64
#  8   PageValues               12221 non-null  float64
#  9   SpecialDay               12221 non-null  float64
#  10  Month                    12221 non-null  object
#  11  OperatingSystems         12221 non-null  int64
#  12  Browser                  12221 non-null  int64
#  13  Region                   12221 non-null  int64
# ...

# %% [markdown]
# ### Связь с целевой переменной

# %%
# Список числовых признаков для анализа
numerical_cols = ['Administrative', 'Administrative_Duration', 'Informational', 
                  'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
                  'BounceRates', 'ExitRates', 'PageValues']

# Построение гистограмм с разбивкой по цветам на значение целевой переменной
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1)
    sns.histplot(data=df, x=col, hue='Revenue', multiple='stack', bins=30, alpha=0.7)
    plt.title(f'Гистограмма {col} по Revenue')
    plt.xlabel(col)
    plt.ylabel('Частота')

plt.tight_layout()
plt.show()

# %%
# Связь получения выручки и просмотра страниц

numerical_cols = ['Revenue', 'Administrative', 'Administrative_Duration', 'Informational', 
                  'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration']

sns.pairplot(df[numerical_cols], hue="Revenue")
plt.show()

# %%
# Связь получения выручки с метриками из "Google Analytics"
numerical_cols = ['Revenue', 'BounceRates', 'ExitRates', 'PageValues']

sns.pairplot(df[numerical_cols], hue="Revenue")
plt.show()

# %%
# Зависимость выручки от значений категориальных переменных

cols = ['SpecialDay', 'Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType', 'Weekend']

plt.figure(figsize=(15, 10))
for i, col in enumerate(cols):
    plt.subplot(3, 3, i + 1)
    sns.barplot(x=col, y='Revenue', data = df, palette='coolwarm')
    plt.title(f'{col} - Revenue')
plt.tight_layout()
plt.show()

# %%
# Влияние значений категориальных признаков на вероятность покупки
cols = ['SpecialDay', 'Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType', 'Weekend']

for i, col in enumerate(cols):
    df_1 = pd.crosstab(df[col], df['Revenue'])
    df_1.div(df_1.sum(1).astype(float), axis=0).plot(kind = 'bar', stacked = True, figsize = (10, 4), color = ['#AAC2F3', '#EAB29B'])

# %% [markdown]
# ### Выводы о связи с целевой переменной
#
# Вероятность покупки выше у новых покупателей, в выходной день, у разных каналов трафика разная эффекивность, пользователи браузеров 12 и 13 совершают покупки чаще, в разные месяцы вероятность покупки меняется.
#
# Есть связь получения выручки с метриками из "Google Analytics".

# %% [markdown]
# ## 3. Построить матрицу корреляций (или ее аналог для категориальных признаков): использовать корреляции, тест χ2, ANOVA

# %%
# Построим матрицу корреляций

corr = df.select_dtypes(include='number').corr() # матрица корреляций

# Настройка размера графика
plt.figure(figsize=(12, 8))

# Построение тепловой карты
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar=True)

# Заголовок графика
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# - Как обозначалось выше, есть связь получения выручки с метриками из "Google Analytics" - средняя положительная корреляция с PageValues и слабая отрицательная корреляция с ExitRates и BouneRates.
# - Также, есть зависимость выручки и просмотренных сраниц / Времени просмотра страниц, особенно для категории ProductRelated и ProductRelated_Duration.
# - Время, проведенное на страницах категории зависит от числа посещенных страниц категории, особенно для ProductRelated страниц.
# - BounceRates и ExitRates имеют самую высокую степень корреляции.
# - BounceRates и ExitRates имеют слабую отрицательную завивимость от количества просмотренных страниц и времени проведенного на них.

# %%
# V-мера Крамера

cols = ['SpecialDay', 'Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType', 'Weekend', 'Revenue']

df_cat = df.apply(lambda x: x.astype("category") if x._name in cols else x)

cramersv = am.CramersV(df_cat)

cramersv.fit()
# Out:
#                   SpecialDay     Month  OperatingSystems   Browser    Region  \
# SpecialDay          1.000000  0.237761          0.036426  0.031542  0.026146
# Month               0.237761  1.000000          0.061935  0.069465  0.045622
# OperatingSystems    0.036426  0.061935          1.000000  0.594720  0.114603
# Browser             0.031542  0.069465          0.594720  1.000000  0.125797
# Region              0.026146  0.045622          0.114603  0.125797  1.000000
# TrafficType         0.117012  0.199345          0.191472  0.189186  0.085438
# VisitorType         0.090843  0.130161          0.053125  0.056268  0.040165
# Weekend             0.260981  0.064912          0.119875  0.087512  0.029911
# Revenue             0.089483  0.175457          0.078437  0.048904  0.028040
#
#                   TrafficType  VisitorType   Weekend   Revenue
# SpecialDay           0.117012     0.090843  0.260981  0.089483
# Month                0.199345     0.130161  0.064912  0.175457
# ...

# %%
sns.heatmap(cramersv.fit(), annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# - V-мера Крамера показывает связь между операционной системой и браузером, типом трафика и типом пользователя, признаком SpecialDay и месяцем.
# - На вероятность получения выручки больше всего вляют месяц и тип трафика.

# %%
# ANOVA

pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

cols_cat = ['SpecialDay', 'Month', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType', 'Weekend', 'Revenue']
cols_num = ['Administrative', 'Administrative_Duration', 'Informational', 'Informational_Duration', 
            'ProductRelated', 'ProductRelated_Duration', 'BounceRates', 'ExitRates', 'PageValues']

Data = []

for c1 in cols_cat:
    for c2 in cols_num:
        CategoryGroupLists = df.groupby(c1)[c2].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        Data.append({'Category' : c1, 'Numerical' : c2, 'Statustic': AnovaResults[0], 'pvalue': AnovaResults[1], 'Is correlated' : AnovaResults[1]<0.5})

AnovaRes = pd.DataFrame.from_dict(Data)
AnovaRes
# Out:
#             Category                Numerical  Statustic  pvalue  \
# 0         SpecialDay           Administrative    26.6864  0.0000
# 1         SpecialDay  Administrative_Duration    14.8342  0.0000
# 2         SpecialDay            Informational     6.7948  0.0000
# 3         SpecialDay   Informational_Duration     2.6153  0.0227
# 4         SpecialDay           ProductRelated     4.2298  0.0008
# 5         SpecialDay  ProductRelated_Duration     5.7349  0.0000
# 6         SpecialDay              BounceRates    24.2477  0.0000
# 7         SpecialDay                ExitRates    38.7101  0.0000
# 8         SpecialDay               PageValues    10.9771  0.0000
# 9              Month           Administrative    33.5867  0.0000
# 10             Month  Administrative_Duration    12.0417  0.0000
# 11             Month            Informational     9.0042  0.0000
# 12             Month   Informational_Duration     4.4914  0.0000
# ...

# %% [markdown]
# Результаты ANOVA показывают, что существует статистически значимое различие в средних значениях между группами для данного числового признака. Это значит, что категориальный признак влияет на числовой признак.

# %% [markdown]
# ## 4. Провести анализ целевой переменной - на какое распределение больше всего похожа ее гистограмма? Какие проблемы в связи с этим могут возникнуть при обучении моделей?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Revenue'], bins=30, kde=True)
plt.title('Распределение Revenue')
plt.xlabel('Revenue')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# ### Целевая переменная Revenue имеет биномиальное распределение, наблюдается значительное несоответствие в распределении классов целевой переменной Revenue. Вероятность совершения покупки составляет всего около 15.6%, в то время как вероятность того, что покупка не состоится, больше 84%.
#
# ### Проблемы, возникающие при обучении моделей с биномиальным распределением
#
# - Многие алгоритмы машинного обучения, такие как линейная регрессия, предполагают нормальность распределения ошибок. Если целевая переменная имеет биномиальное распределение, это предположение нарушается, что может привести к неточным предсказаниям и выводам.
#
# - Для работы с биномиальными данными могут потребоваться специальные методы, такие как логистическая регрессия или другие
#
# ### Проблемы, связанные с несбалансированными классами
#
# - Смещение модели в сторону мажоритарного класса:
# Модели могут иметь тенденцию классифицировать все примеры как принадлежащие к мажоритарному классу. Это происходит, потому что модели обучаются на данных, где один класс представлен значительно чаще. Например, модель может достичь высокой точности, просто предсказывая этот класс для всех наблюдений, игнорируя меньшинство.
#
# - Искажение метрик оценки:
# Классические метрики, такие как точность (accuracy), могут вводить в заблуждение при оценке моделей на несбалансированных данных. Высокая точность может быть достигнута за счет игнорирования менее представленного класса.
#
# - Недостаточное количество примеров для миноритарного класса:
# Меньшее количество примеров в классе-меньшинстве затрудняет обучение модели, так как у нее недостаточно информации для выявления паттернов и особенностей этого класса. Это может привести к низкой способности модели обнаруживать и правильно классифицировать примеры из миноритарного класса.

# %% [markdown]
# ## 5. Увеличить размер данных простым дублированием до 1_000_000 строк в датасете. Провести сравнение скорости работы Pandas и Polars на увеличенном датасете по параметрам:
# - загрузка данных
# - фильтрация данных
# - агрегация данных

# %%
df_big = df.copy()

for i in range(round(1000000/df.shape[0])-1):
  df_big = pd.concat([df_big, df])

df_big = df_big.sample(1000000)
df_big.sample(1000000).to_csv("big.csv", index=False)

# %%
df.shape, df_big.shape
# Out:
# ((12221, 18), (1000000, 18))

# %% [markdown]
# #### Загрузка данных

# %%
# %%time

df = pd.read_csv("big.csv")
# Out:
# CPU times: total: 2.38 s
# Wall time: 2.68 s

# %%
# %%time

df_pl = pl.read_csv("big.csv")
# Out:
# CPU times: total: 1.53 s
# Wall time: 628 ms

# %% [markdown]
# #### Фильтрация данных

# %%
# %%time

df[(df['VisitorType'] == 'Returning_Visitor') & (df['Revenue'] == 1)].head()
# Out:
# CPU times: total: 109 ms
# Wall time: 120 ms
#     Administrative  Administrative_Duration  Informational  \
# 6                2                 137.0000              0
# 8                9                 255.4167              2
# 14               0                   0.0000              1
# 19               1                   4.0000              0
# 37               1                  81.0000              0
#
#     Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 6                   0.0000               6                 185.4000
# 8                  94.1667              22                 612.8194
# 14                  0.0000              46                2183.8875
# 19                  0.0000              20                 471.4778
# 37                  0.0000              93                3359.6250
#
#     BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 6        0.0000     0.0286     44.8935      0.0000   Oct                 2
# ...

# %%
# %%time

df_pl.filter((pl.col('VisitorType') == 'Returning_Visitor') & (pl.col('Revenue') == 1)).head()
# Out:
# CPU times: total: 62.5 ms
# Wall time: 101 ms
# shape: (5, 18)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬─────────┬─────────┐
# │ Administra ┆ Administra ┆ Informatio ┆ Informati ┆ … ┆ TrafficTy ┆ VisitorTy ┆ Weekend ┆ Revenue │
# │ tive       ┆ tive_Durat ┆ nal        ┆ onal_Dura ┆   ┆ pe        ┆ pe        ┆ ---     ┆ ---     │
# │ ---        ┆ ion        ┆ ---        ┆ tion      ┆   ┆ ---       ┆ ---       ┆ i64     ┆ i64     │
# │ i64        ┆ ---        ┆ i64        ┆ ---       ┆   ┆ i64       ┆ str       ┆         ┆         │
# │            ┆ f64        ┆            ┆ f64       ┆   ┆           ┆           ┆         ┆         │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═════════╪═════════╡
# │ 2          ┆ 137.0      ┆ 0          ┆ 0.0       ┆ … ┆ 4         ┆ Returning ┆ 0       ┆ 1       │
# │            ┆            ┆            ┆           ┆   ┆           ┆ _Visitor  ┆         ┆         │
# ...

# %% [markdown]
# #### Агрегация данных

# %%
# %%time

df.groupby('Month').agg({'ProductRelated' : 'mean', 'ProductRelated_Duration' : 'max'})
# Out:
# CPU times: total: 93.8 ms
# Wall time: 108 ms
#        ProductRelated  ProductRelated_Duration
# Month
# Aug           37.3318               23342.0821
# Dec           28.3382               63973.5222
# Feb           11.3463                6951.9722
# Jul           36.5560               23050.1041
# June          36.4393               16093.3094
# Mar           20.1398               12983.7877
# May           26.7334               43171.2334
# Nov           46.2478               27009.8594
# Oct           33.5337               11976.7213
# Sep           33.1585               23888.8100

# %%
# %%time

df_pl.group_by('Month').agg([pl.mean('ProductRelated'), pl.max('ProductRelated_Duration')])
# Out:
# CPU times: total: 109 ms
# Wall time: 103 ms
# shape: (10, 3)
# ┌───────┬────────────────┬─────────────────────────┐
# │ Month ┆ ProductRelated ┆ ProductRelated_Duration │
# │ ---   ┆ ---            ┆ ---                     │
# │ str   ┆ f64            ┆ f64                     │
# ╞═══════╪════════════════╪═════════════════════════╡
# │ Nov   ┆ 46.24784       ┆ 27009.85943             │
# │ Oct   ┆ 33.533742      ┆ 11976.72135             │
# │ Sep   ┆ 33.158482      ┆ 23888.81                │
# │ May   ┆ 26.733399      ┆ 43171.23338             │
# │ June  ┆ 36.43935       ┆ 16093.30941             │
# │ Feb   ┆ 11.346325      ┆ 6951.972222             │
# │ Mar   ┆ 20.139791      ┆ 12983.78771             │
# │ Aug   ┆ 37.331845      ┆ 23342.08205             │
# │ Dec   ┆ 28.338204      ┆ 63973.52223             │
# │ Jul   ┆ 36.555951      ┆ 23050.10414             │
# └───────┴────────────────┴─────────────────────────┘

# %%
# %%time

q = (
    df_pl
    .lazy()
    .group_by(by='Month')
    .agg(
        [
            pl.col('ProductRelated').mean(),
            pl.col('ProductRelated_Duration').max()
        ]
    )
)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time

q.collect()
# Out:
# CPU times: total: 78.1 ms
# Wall time: 40.1 ms
# shape: (10, 3)
# ┌──────┬────────────────┬─────────────────────────┐
# │ by   ┆ ProductRelated ┆ ProductRelated_Duration │
# │ ---  ┆ ---            ┆ ---                     │
# │ str  ┆ f64            ┆ f64                     │
# ╞══════╪════════════════╪═════════════════════════╡
# │ May  ┆ 26.733399      ┆ 43171.23338             │
# │ Dec  ┆ 28.338204      ┆ 63973.52223             │
# │ Mar  ┆ 20.139791      ┆ 12983.78771             │
# │ Jul  ┆ 36.555951      ┆ 23050.10414             │
# │ Aug  ┆ 37.331845      ┆ 23342.08205             │
# │ Nov  ┆ 46.24784       ┆ 27009.85943             │
# │ Oct  ┆ 33.533742      ┆ 11976.72135             │
# │ June ┆ 36.43935       ┆ 16093.30941             │
# │ Sep  ┆ 33.158482      ┆ 23888.81                │
# │ Feb  ┆ 11.346325      ┆ 6951.972222             │
# └──────┴────────────────┴─────────────────────────┘

# %% [markdown]
# ## Сравнение скорости работы Pandas и Polars - Выводы
#
# - В загрузке и фильтрации данных Polars паказал лучшие результаты по времени.
# - C группировкой Pandas справился немного быстрее, но с использованием lazy operations, Polars и при агрегации немного выигрывает.
